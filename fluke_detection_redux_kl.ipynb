# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from fastai.vision import *
from fastai.metrics import accuracy
from fastai.basic_data import *
from skimage.util import montage
from fastai.callbacks.hooks import num_features_model
from torch.nn import L1Loss
import pandas as pd
from torch import optim
import re
import json
import cv2
import types

from utils import *

# %%
j = json.load(open('data/boxes.json'))

# %%
j[0]
# Out:
# {'annotations': [{'class': 'fluke',
#    'height': 372.0,
#    'type': 'rect',
#    'width': 1017.0,
#    'x': 14.0,
#    'y': 97.0}],
#  'class': 'image',
#  'filename': '6138dce83.jpg'}

# %% [markdown]
# The above annotations are in coco dataset format (x, y, width, height). The fastai library expects bbox coordinates to be in the format of (y_upper_left, x_upper_left, y_lower_right, x_lower_right) with the origin being in the upper left hand corner of the image.

# %%
#KL: Original SZ = 224
SZ = 448
#KL: Original BS = 64
BS = 32
NUM_WORKERS = 8

# %%
def anno2bbox(anno):
    im_width, im_height = PIL.Image.open(f"data/train/{anno['filename']}").size
    anno = anno['annotations'][0]
    return [
        np.clip(anno['y'], 0, im_height) / im_height * SZ,
        np.clip(anno['x'], 0, im_width) / im_width * SZ,
        np.clip(anno['y']+anno['height'], 0, im_height) / im_height * SZ,
        np.clip(anno['x']+anno['width'], 0, im_width) / im_width * SZ
    ]

# %% [markdown]
# Just some small functions that will be helpful as we construct our dataset.

# %%
fn2bbox = {jj['filename']: [[anno2bbox(jj)], [anno['class'] for anno in jj['annotations']]] for jj in j}
path2fn = lambda path: re.search('\w*\.jpg$', path).group(0)
get_y_func = lambda o: fn2bbox[path2fn(o)]
#get_y_func = lambda o: [list(bbox) for bbox in fn2bbox[path2fn(o)]]

# %%
val_fns = pd.read_pickle('data/val_fns_detection.pkl') # I create this file in fluke_detection.ipynb

# %% [markdown]
# ObjectCategoryList is designed to be used in a full object recognition scenario (multiple bounding boxes per image, objects of multiple classes). Since that is more functionality than we require (and more than our model will predict - our objects will always be of the same class, fluke, and we will be predicting just a single bounding box per image) I make minor changes to ObjectCategoryList.

# %%
class StubbedObjectCategoryList(ObjectCategoryList):
    def analyze_pred(self, pred): return [pred.unsqueeze(0), torch.ones(1).long()]

# %%
data = (ObjectItemList.from_df(pd.DataFrame(data=list(fn2bbox.keys())), path=f'data/train-{SZ}')
        .split_by_valid_func(lambda path: path2fn(path) in val_fns)                         
        .label_from_func(get_y_func, label_cls=StubbedObjectCategoryList)
        .transform(get_transforms(max_zoom=1, max_warp=0.05, max_rotate=0.05, max_lighting=0.2), tfm_y=True, size=(SZ,SZ), resize_method=ResizeMethod.SQUISH)
        .databunch(bs=BS, num_workers=NUM_WORKERS)
        .normalize(imagenet_stats))

# %%
#KL: This line gave me an error need to edit a fastai file to fix:
#Go to the ImageBBox class’s create() function. Put bboxes = [list(bbox) for bbox in bboxes] on the first line there.
data.show_batch(rows=3, ds_type=DatasetType.Valid, figsize=(12,12))

# %%
class FlukeDetector(nn.Module):
    def __init__(self, arch=models.resnet18):
        super().__init__() 
        self.cnn = create_body(arch)
        self.head = create_head(num_features_model(self.cnn) * 2, 4)
        
    def forward(self, im):
        x = self.cnn(im)
        x = self.head(x)
        return 2 * (x.sigmoid_() - 0.5)

# %%
def loss_fn(preds, targs, class_idxs):
    return L1Loss()(preds, targs.squeeze())

# %%
learn = Learner(data, FlukeDetector(arch=models.resnet50), loss_func=loss_fn)
learn.metrics = [lambda preds, targs, _: IoU(preds, targs.squeeze()).mean()]

# %%
learn.split([learn.model.cnn[:6], learn.model.cnn[6:], learn.model.head])

# %%
learn.freeze_to(-1)

# %%
#KL: Needed to copy this definition from fluke_detection to avoid error in learn.fit_one_cycle
def intersection(preds, targs):
    # preds and targs are of shape (bs, 4), pascal_voc format
    max_xy = torch.min(preds[:, 2:], targs[:, 2:])
    min_xy = torch.max(preds[:, :2], targs[:, :2])
    inter = torch.clamp((max_xy - min_xy), min=0)
    return inter[:, 0] * inter[:, 1]

def area(boxes): 
    return ((boxes[:, 2]-boxes[:, 0]) * (boxes[:, 3]-boxes[:, 1]))

def union(preds, targs):
    return area(preds) + area(targs) - intersection(preds, targs)

def IoU(preds, targs):
    return intersection(preds, targs) / union(preds, targs)

# %%
learn.fit_one_cycle(10, 1e-2)
# Out:
# Total time: 01:43 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th><lambda></th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.777199</th>
#     <th>0.708357</th>
#     <th>0.001176</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.737604</th>
#     <th>0.594360</th>
#     <th>0.067593</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.572949</th>
#     <th>0.158065</th>
#     <th>0.660382</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.432725</th>
#     <th>0.167040</th>
#     <th>0.641833</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.346202</th>
#     <th>0.126479</th>
#     <th>0.680890</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.288236</th>
#     <th>0.105784</th>
#     <th>0.738992</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.244859</th>
#     <th>0.099673</th>
#     <th>0.733352</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.214105</th>
#     <th>0.102584</th>
#     <th>0.738531</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.190629</th>
#     <th>0.098738</th>
#     <th>0.747121</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.171231</th>
#     <th>0.094537</th>
#     <th>0.755092</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.unfreeze()

# %%
max_lr = 2e-3
lrs = [max_lr/100, max_lr/10, max_lr]

# %%
learn.fit_one_cycle(40, lrs, div_factor=20)
# Out:
# Total time: 08:22 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th><lambda></th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.089875</th>
#     <th>0.089683</th>
#     <th>0.767269</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.089380</th>
#     <th>0.088234</th>
#     <th>0.770264</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.088543</th>
#     <th>0.087545</th>
#     <th>0.771196</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.088144</th>
#     <th>0.084468</th>
#     <th>0.776537</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.087861</th>
#     <th>0.081369</th>
#     <th>0.781972</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.088160</th>
#     <th>0.083701</th>
#     <th>0.776990</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.087866</th>
#     <th>0.084417</th>
#     <th>0.771968</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.087001</th>
#     <th>0.082960</th>
#     <th>0.770581</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.085780</th>
#     <th>0.089141</th>
#     <th>0.759895</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.083909</th>
#     <th>0.084306</th>
#     <th>0.779374</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.083306</th>
#     <th>0.092906</th>
#     <th>0.758969</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.082630</th>
#     <th>0.091327</th>
#     <th>0.763416</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.081223</th>
#     <th>0.079710</th>
#     <th>0.780094</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.079406</th>
#     <th>0.075932</th>
#     <th>0.793272</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.078258</th>
#     <th>0.068098</th>
#     <th>0.807749</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.075479</th>
#     <th>0.065137</th>
#     <th>0.809878</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.074457</th>
#     <th>0.065428</th>
#     <th>0.812368</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.072923</th>
#     <th>0.055254</th>
#     <th>0.835611</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.070837</th>
#     <th>0.060381</th>
#     <th>0.818186</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.069261</th>
#     <th>0.056774</th>
#     <th>0.832426</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>0.067795</th>
#     <th>0.055121</th>
#     <th>0.841703</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>0.066349</th>
#     <th>0.053350</th>
#     <th>0.843502</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>0.064503</th>
#     <th>0.052967</th>
#     <th>0.845982</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>0.063269</th>
#     <th>0.049621</th>
#     <th>0.854629</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>0.061119</th>
#     <th>0.049349</th>
#     <th>0.851435</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>0.059549</th>
#     <th>0.053628</th>
#     <th>0.844334</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>0.058388</th>
#     <th>0.052512</th>
#     <th>0.847255</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>0.058360</th>
#     <th>0.056387</th>
#     <th>0.834019</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>0.056670</th>
#     <th>0.049411</th>
#     <th>0.853254</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>0.055128</th>
#     <th>0.053926</th>
#     <th>0.842013</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>0.054058</th>
#     <th>0.048885</th>
#     <th>0.856955</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>0.053345</th>
#     <th>0.045933</th>
#     <th>0.863193</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>0.052209</th>
#     <th>0.045399</th>
#     <th>0.863194</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>0.051316</th>
#     <th>0.045970</th>
#     <th>0.860571</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>0.050251</th>
#     <th>0.046433</th>
#     <th>0.860015</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>0.049912</th>
#     <th>0.046977</th>
#     <th>0.859144</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>0.049427</th>
#     <th>0.045436</th>
#     <th>0.864467</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>0.049220</th>
#     <th>0.045737</th>
#     <th>0.863785</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>0.048545</th>
#     <th>0.046095</th>
#     <th>0.862801</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>0.048151</th>
#     <th>0.046146</th>
#     <th>0.863224</th>
#   </tr>
# </table>

# %%
max_lr = 1e-2
lrs = [max_lr/100, max_lr/10, max_lr]
learn.fit_one_cycle(10, lrs, div_factor=20)
max_lr = 2e-3
lrs = [max_lr/100, max_lr/10, max_lr]
learn.fit_one_cycle(20, lrs, div_factor=20)
max_lr = 1e-2
lrs = [max_lr/100, max_lr/10, max_lr]
learn.fit_one_cycle(10, lrs, div_factor=20)
max_lr = 2e-3
lrs = [max_lr/100, max_lr/10, max_lr]
learn.fit_one_cycle(20, lrs, div_factor=20)
max_lr = 1e-2
lrs = [max_lr/100, max_lr/10, max_lr]
learn.fit_one_cycle(10, lrs, div_factor=20)
max_lr = 2e-3
lrs = [max_lr/100, max_lr/10, max_lr]
learn.fit_one_cycle(20, lrs, div_factor=20)
max_lr = 2e-4
lrs = [max_lr/100, max_lr/10, max_lr]
learn.fit_one_cycle(20, lrs, div_factor=20)
max_lr = 2e-5
lrs = [max_lr/100, max_lr/10, max_lr]
learn.fit_one_cycle(20, lrs, div_factor=20)
# Out:
# Total time: 02:03 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th><lambda></th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.045138</th>
#     <th>0.050461</th>
#     <th>0.848806</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.050031</th>
#     <th>0.080007</th>
#     <th>0.783401</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.060768</th>
#     <th>0.098059</th>
#     <th>0.754048</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.073788</th>
#     <th>0.208486</th>
#     <th>0.553715</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.085749</th>
#     <th>0.220381</th>
#     <th>0.593174</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.086274</th>
#     <th>0.148650</th>
#     <th>0.682370</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.084040</th>
#     <th>0.107097</th>
#     <th>0.750602</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.083246</th>
#     <th>0.073448</th>
#     <th>0.811039</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.081530</th>
#     <th>0.057035</th>
#     <th>0.835954</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.079378</th>
#     <th>0.059712</th>
#     <th>0.830347</th>
#   </tr>
# </table>
# Total time: 04:08 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th><lambda></th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.067158</th>
#     <th>0.064666</th>
#     <th>0.824410</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.068269</th>
#     <th>0.058963</th>
#     <th>0.833771</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.065934</th>
#     <th>0.073871</th>
#     <th>0.810720</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.066273</th>
#     <th>0.073668</th>
#     <th>0.811524</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.066935</th>
#     <th>0.060952</th>
#     <th>0.834470</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.064510</th>
#     <th>0.060781</th>
#     <th>0.829526</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.064748</th>
#     <th>0.062815</th>
#     <th>0.825110</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.064596</th>
#     <th>0.053547</th>
#     <th>0.843052</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.063891</th>
#     <th>0.055625</th>
#     <th>0.839182</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.062492</th>
#     <th>0.048542</th>
#     <th>0.851450</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.064060</th>
#     <th>0.064923</th>
#     <th>0.823448</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.063982</th>
#     <th>0.069617</th>
#     <th>0.829698</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.063195</th>
#     <th>0.072276</th>
#     <th>0.818785</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.062810</th>
#     <th>0.067538</th>
#     <th>0.831585</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.061908</th>
#     <th>0.060124</th>
#     <th>0.842894</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.059667</th>
#     <th>0.052894</th>
#     <th>0.851197</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.059104</th>
#     <th>0.048841</th>
#     <th>0.858143</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.058137</th>
#     <th>0.049425</th>
#     <th>0.855870</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.057129</th>
#     <th>0.048278</th>
#     <th>0.860363</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.055902</th>
#     <th>0.048458</th>
#     <th>0.858574</th>
#   </tr>
# </table>
# Total time: 02:04 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th><lambda></th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.052544</th>
#     <th>0.045619</th>
#     <th>0.863454</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.057328</th>
#     <th>0.063620</th>
#     <th>0.823662</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.063695</th>
#     <th>0.121298</th>
#     <th>0.698883</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.070452</th>
#     <th>0.089701</th>
#     <th>0.765361</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.075053</th>
#     <th>0.181267</th>
#     <th>0.632564</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.077274</th>
#     <th>0.208230</th>
#     <th>0.603699</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.076187</th>
#     <th>0.085862</th>
#     <th>0.779664</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.075273</th>
#     <th>0.064709</th>
#     <th>0.825172</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.072578</th>
#     <th>0.058239</th>
#     <th>0.834607</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.070194</th>
#     <th>0.055163</th>
#     <th>0.840094</th>
#   </tr>
# </table>
# Total time: 04:09 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th><lambda></th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.061418</th>
#     <th>0.054865</th>
#     <th>0.843147</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.059186</th>
#     <th>0.052501</th>
#     <th>0.849816</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.058065</th>
#     <th>0.054249</th>
#     <th>0.843694</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.059160</th>
#     <th>0.053783</th>
#     <th>0.846003</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.058118</th>
#     <th>0.051590</th>
#     <th>0.848967</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.057606</th>
#     <th>0.052916</th>
#     <th>0.845677</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.057205</th>
#     <th>0.057728</th>
#     <th>0.833060</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.057295</th>
#     <th>0.049638</th>
#     <th>0.856144</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.057680</th>
#     <th>0.052186</th>
#     <th>0.849226</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.057594</th>
#     <th>0.050258</th>
#     <th>0.857023</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.058023</th>
#     <th>0.050260</th>
#     <th>0.857759</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.057619</th>
#     <th>0.049546</th>
#     <th>0.856896</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.056232</th>
#     <th>0.044541</th>
#     <th>0.871170</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.055172</th>
#     <th>0.046592</th>
#     <th>0.866468</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.055155</th>
#     <th>0.052680</th>
#     <th>0.846630</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.054742</th>
#     <th>0.044234</th>
#     <th>0.871007</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.054858</th>
#     <th>0.042548</th>
#     <th>0.877774</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.053782</th>
#     <th>0.041627</th>
#     <th>0.880375</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.052609</th>
#     <th>0.041857</th>
#     <th>0.879480</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.051477</th>
#     <th>0.041866</th>
#     <th>0.879896</th>
#   </tr>
# </table>
# Total time: 02:03 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th><lambda></th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.050821</th>
#     <th>0.050235</th>
#     <th>0.852103</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.054834</th>
#     <th>0.057257</th>
#     <th>0.826337</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.057413</th>
#     <th>0.061585</th>
#     <th>0.830505</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.064373</th>
#     <th>0.084198</th>
#     <th>0.748297</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.067741</th>
#     <th>0.100681</th>
#     <th>0.749838</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.067837</th>
#     <th>0.077179</th>
#     <th>0.779643</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.067679</th>
#     <th>0.069458</th>
#     <th>0.807064</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.066655</th>
#     <th>0.059090</th>
#     <th>0.833942</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.065843</th>
#     <th>0.054517</th>
#     <th>0.844086</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.064606</th>
#     <th>0.053345</th>
#     <th>0.848692</th>
#   </tr>
# </table>
# Total time: 04:09 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th><lambda></th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.061151</th>
#     <th>0.052348</th>
#     <th>0.851833</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.059058</th>
#     <th>0.051098</th>
#     <th>0.855316</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.057728</th>
#     <th>0.051665</th>
#     <th>0.850984</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.056182</th>
#     <th>0.046564</th>
#     <th>0.865145</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.055188</th>
#     <th>0.048988</th>
#     <th>0.857635</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.054059</th>
#     <th>0.043967</th>
#     <th>0.874618</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.054441</th>
#     <th>0.048154</th>
#     <th>0.859261</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.055057</th>
#     <th>0.049374</th>
#     <th>0.859560</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.055169</th>
#     <th>0.045771</th>
#     <th>0.868702</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.053533</th>
#     <th>0.042672</th>
#     <th>0.873282</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.052406</th>
#     <th>0.042853</th>
#     <th>0.876215</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.050949</th>
#     <th>0.042965</th>
#     <th>0.873980</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.050893</th>
#     <th>0.041534</th>
#     <th>0.878531</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.050275</th>
#     <th>0.045592</th>
#     <th>0.870419</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.049786</th>
#     <th>0.045926</th>
#     <th>0.872123</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.048558</th>
#     <th>0.042104</th>
#     <th>0.878576</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.047730</th>
#     <th>0.041052</th>
#     <th>0.880491</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.047130</th>
#     <th>0.040907</th>
#     <th>0.881514</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.046350</th>
#     <th>0.040738</th>
#     <th>0.882833</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.046260</th>
#     <th>0.040827</th>
#     <th>0.882528</th>
#   </tr>
# </table>
# Total time: 04:09 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th><lambda></th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.047322</th>
#     <th>0.041331</th>
#     <th>0.881207</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.046217</th>
#     <th>0.041763</th>
#     <th>0.879495</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.046233</th>
#     <th>0.041243</th>
#     <th>0.881291</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.045845</th>
#     <th>0.040869</th>
#     <th>0.882220</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.044901</th>
#     <th>0.040656</th>
#     <th>0.882143</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.044526</th>
#     <th>0.041194</th>
#     <th>0.880609</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.044365</th>
#     <th>0.042051</th>
#     <th>0.877689</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.045028</th>
#     <th>0.040877</th>
#     <th>0.881618</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.045780</th>
#     <th>0.040975</th>
#     <th>0.881351</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.046077</th>
#     <th>0.040288</th>
#     <th>0.883195</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.045641</th>
#     <th>0.039109</th>
#     <th>0.885688</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.044946</th>
#     <th>0.039058</th>
#     <th>0.885934</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.044127</th>
#     <th>0.039138</th>
#     <th>0.886452</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.043662</th>
#     <th>0.039279</th>
#     <th>0.886033</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.044015</th>
#     <th>0.039992</th>
#     <th>0.884403</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.044268</th>
#     <th>0.039709</th>
#     <th>0.885130</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.043931</th>
#     <th>0.039760</th>
#     <th>0.885006</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.043865</th>
#     <th>0.040264</th>
#     <th>0.883479</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.044157</th>
#     <th>0.039287</th>
#     <th>0.886380</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.043614</th>
#     <th>0.039222</th>
#     <th>0.886354</th>
#   </tr>
# </table>
# Total time: 04:08 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th><lambda></th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.042549</th>
#     <th>0.039180</th>
#     <th>0.886239</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.040100</th>
#     <th>0.039205</th>
#     <th>0.886391</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.042917</th>
#     <th>0.040024</th>
#     <th>0.884674</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.043687</th>
#     <th>0.039325</th>
#     <th>0.886180</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.044004</th>
#     <th>0.039561</th>
#     <th>0.885475</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.043560</th>
#     <th>0.039030</th>
#     <th>0.886924</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.043067</th>
#     <th>0.039660</th>
#     <th>0.885121</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.042581</th>
#     <th>0.038805</th>
#     <th>0.887336</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.042631</th>
#     <th>0.039411</th>
#     <th>0.886010</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.042595</th>
#     <th>0.039168</th>
#     <th>0.886464</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.042819</th>
#     <th>0.038918</th>
#     <th>0.886958</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.043564</th>
#     <th>0.038426</th>
#     <th>0.888101</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.042329</th>
#     <th>0.039025</th>
#     <th>0.886912</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.042671</th>
#     <th>0.039203</th>
#     <th>0.886937</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.043398</th>
#     <th>0.039182</th>
#     <th>0.886898</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.043394</th>
#     <th>0.038926</th>
#     <th>0.886997</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.043766</th>
#     <th>0.038655</th>
#     <th>0.888226</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.043633</th>
#     <th>0.039128</th>
#     <th>0.886359</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.043536</th>
#     <th>0.039063</th>
#     <th>0.886660</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.043189</th>
#     <th>0.039129</th>
#     <th>0.886316</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.show_results(rows=6)

# %%
learn.save('../../models/bounding_boxes_v0')

# %%
preds, targs = learn.get_preds()

predicted_bboxes = ((preds + 1) / 2 * SZ).numpy()
targets = ((targs + 1) / 2 * SZ).numpy().squeeze()

def draw_bbox(img, bbox, target=None, color=(255, 0, 0), thickness=2):
    y_min, x_min, y_max, x_max = map(int, bbox)
    cv2.rectangle(img, (x_min, y_min), (x_max, y_max), color=color, thickness=thickness)
    if target is not None:
        y_min, x_min, y_max, x_max = map(int, target)
        cv2.rectangle(img, (x_min, y_min), (x_max, y_max), color=(0,255,0), thickness=thickness)
    return img

def cv_read(path):    
    im = cv2.imread(path, cv2.IMREAD_COLOR)
    return cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# Targets are in green, predictions in red.
ims = np.stack([draw_bbox(cv_read(data.valid_ds.items[i]), predicted_bboxes[i], targets[i]) for i in range(9)])
plt.figure(figsize=(12,12))
plt.axis('off')
plt.imshow(montage(np.stack(ims), multichannel=True))

# %%
print(data.valid_ds.items[0])
im = cv2.imread(data.valid_ds.items[0], cv2.IMREAD_COLOR)
im = cv2.imread('data/test/68f340d0c.jpg', cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
# Out:
# data/train-448/./0dcfd05bf.jpg
